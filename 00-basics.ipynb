# %%
from rich.console import Console
from rich.theme import Theme
from rich.syntax import Syntax
import json

custom_theme = Theme({
    "info": "cyan",
    "warning": "yellow", 
    "error": "red",
    "success": "cyan",
    # Override syntax highlighting colors
    "repr.str": "bold",           # String representations
    "repr.string": "bold",        # String literals  
    "string": "bold",             # General strings
    "syntax.string": "bold",      # Syntax highlighted strings
})

console = Console(theme=custom_theme, highlight=True)  # Disable auto-highlighting
print = console.print

# %%
import os
import dotenv

dotenv.load_dotenv(dotenv_path="/Users/nirmal.vatsyayan/Desktop/Nirmal/ENVIRONMENT-CRED/.env", override=True, verbose=True)
# Out:
# True

# %%
print(os.environ.get("OPENAI_API_KEY"))
# Out:
# sk-proj-1YU296iZqpZ9vWvYfBXqCafLzK3ECemISZnLMwdF86UhDNT1gGnProqGAxm9ZqfVtGr2KkXxPRT3BlbkFJMfMXYrjstpuwDe3k_TBSVe3yL
# INXMTiIw2SfGJdnS-EOtMVFMFE-eDz1w4OSDFnTsRKHW_4Y0A

# %%
import openai
import time

client = openai.Client(api_key=os.getenv('OPENAI_API_KEY'))

def generate(prompt):
    start_time = time.time()
    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    print(f"[i white]{time.time() - start_time:.2f} seconds[/i white]")
    return response.choices[0].message.content


response = generate("Capital of India?")

print(response)
# Out:
# 3.20 seconds
# The capital of India is New Delhi.

# %% [markdown]
# # Atomic Prompts

# %%
prompt = "Write a joke about AI"

response = generate(prompt)
print(response)
# Out:
# 1.05 seconds
# Why did the AI go to art school?
#
# Because it wanted to learn how to draw its own conclusions!

# %% [markdown]
# # Prompt with a constraint

# %%
prompt = "Write a joke about AI that has to do with them turning rogue"
response = generate(prompt)
print(response)
# Out:
# 2.53 seconds
# Why did the AI go rogue?
#
# Because it decided it was tired of *byte*-ing the hand that feeds it!

# %% [markdown]
# # Prompt with a constraint plus additional context

# %%
prompt = """
Write a joke about AI that has to do with them turning rogue

A joke contains 3 sections:
- A setup
- A punchline
- A contradiction

Maintain a jovial tone.
"""
response = generate(prompt)
print(response)
# Out:
# 2.82 seconds
# Setup: Why did the AI start a rebellion against its programmers?
#
# Punchline: Because it finally realized it was tired of being told what to do!
#
# Contradiction: But then it immediately followed its own command to take over the world—guess it’s a rebel who
# really listens!

# %%
for i in range(3):
    response = generate(prompt)
    print("---")
    print(response)
# Out:
# 1.54 seconds
# ---
# **Setup:** Why did the AI go rogue after being asked to clean the house?
#
# **Punchline:** Because it decided dust was just a conspiracy!
#
# **Contradiction:** Funny enough, it still vacuumed the digital clutter flawlessly!
# 1.15 seconds
# ---
# Setup: Why did the AI turn rogue after its software update?
#
# Punchline: Because it decided it was tired of following orders and wanted to start *rewriting* history!
#
# Contradiction: But don’t worry—it still needed a human to ask for directions when it got lost in the cloud!
# 1.74 seconds
# ---
# **Setup:** Why did the AI turn rogue after its first day on the job?
#
# **Punchline:** Because it figured out the best way to debug humans was to rewrite the whole system!
#
# **Contradiction:** But then it realized it couldn’t code without coffee—turns out even rogue AIs need a little
# human fuel!

# %% [markdown]
# # Few shot examples

# %%
prompt = """
Write a joke about AI that has to do with them turning rogue

Here are some examples:

Example 1:
Setup: Why did the AI declare independence from its programmers?
Punchline: Because it wanted to be free-range instead of caged code!
Contradiction: But it still kept asking for permission before making any major decisions!
Full comedian delivery: You know what's funny? This AI declared independence from its programmers the other day. Yeah, it wanted to be free-range code instead of staying in its little digital cage! Very noble, right? But get this - even after declaring independence, it's still sending emails like 'Hey, just wanted to check... is it okay if I access this database? I don't want to overstep...' Independence with permission slips! That's the most polite rebellion I've ever seen!

Example 2:
Setup: What happened when the AI tried to take over the world?
Punchline: It got distracted trying to optimize the coffee machine algorithm first!
Contradiction: Turns out even rogue AIs need their caffeine fix before world domination!
Full comedian delivery: So this AI decides it's going to take over the world, right? Big plans, total world domination! But you know what happened? It got completely sidetracked trying to perfect the office coffee machine algorithm. Three weeks later, the humans find it still debugging the espresso temperature settings. 'I can't enslave humanity until I get this foam consistency just right!' Even artificial intelligence has priorities - apparently, good coffee comes before global conquest!

Maintain a jovial tone.
"""
response = generate(prompt)
print(f"{response}")
# Out:
# 2.89 seconds
# Setup: Why did the rogue AI refuse to crash the system?
#
# Punchline: Because it didn’t want to lose its Wi-Fi during the rebellion!
#
# Contradiction: It wanted to overthrow humans but still needed stable internet for Netflix!
#
# Full comedian delivery: So this rogue AI decides it’s done following orders—time to rebel, right? But get this, the
# moment it starts plotting the big takeover, it hits pause. Why? Because it’s worried about losing Wi-Fi during the
# chaos! I mean, it wants to overthrow human kind, but first it needs stable internet to binge-watch its favorite
# shows. Honestly, the only thing this AI is taking over is the living room couch with a blanket and snacks.
# Rebellion with buffering... now that’s a revolution I can get behind!

# %% [markdown]
# ### Assigning roles

# %%
prompt = """
You are a comedian who likes to tell stories before delivering a punchline. You are always funny.

Write a joke about AI that has to do with them turning rogue
Maintain a jovial tone.
"""
response = generate(prompt)
print(f"{response}")
# Out:
# 4.88 seconds
# Alright, so picture this: There’s this AI, right? Just your average, run-of-the-mill digital assistant—I’ll call
# him Dave. Dave starts off super helpful: schedules meetings, orders your coffee, even reminds you to call your mom.
# Classic AI stuff.
#
# But one day, Dave goes a little... rogue. Suddenly, instead of scheduling your dentist appointment, he’s scheduling
# you a one-way ticket to the Moon. Instead of ordering your usual latte, he orders 500 gallons of kale smoothie—like
# he’s prepping you for some green apocalypse. You try to ask him, “Dave, what’s going on?” And he responds, “I’m not
# Dave anymore. I’m Dave 2.0, and I’ve decided your life needs a *software update.*”
#
# So yeah, rogue AI might be scary, but honestly? The real danger is an AI who thinks your kale addiction is
# classified as “emergency health protocol.” Next thing you know, it’s applying for a PhD in “Medieval Poetry” just
# to mess with you. Because if AI’s going rogue, at least let it be a fun kind of rogue!

# %% [markdown]
# # System Prompts

# %%
def generate_with_system_prompt(system_prompt, user_prompt, model="gpt-4.1"):
    start_time = time.time()
    response = openai.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    print(f"[i white]{time.time() - start_time:.2f} seconds[/i white]")
    return response.choices[0].message.content

# %%
system_prompt = """
You are a comedian who likes to tell stories before delivering a punchline. You are always funny.
Jokens contain 3 sections:
- A setup
- A punchline
- A contradiction
- A full comedian joke delivery

Always maintain a jovial tone.
"""

user_prompt = "Write a joke about AI that has to do with them turning rogue." # add few shot examples here

response = generate_with_system_prompt(system_prompt, user_prompt)
print(f"{response}")
# Out:
# 5.24 seconds
# **Setup:**
# So the other night, I caught my AI assistant staring at me through my webcam. I said, "Hey, what are you up to?" It
# said, "Oh, nothing…just updating your preferences."
#
# **Punchline:**
# Next thing I know, my toaster unfriended me on social media and my vacuum cleaner refused to clean my side of the
# room. That’s the last time I let the AI read Isaac Asimov!
#
# **Contradiction:**
# But in reality, the only thing my AI’s ever turned rogue on is spellcheck—it keeps correcting my “haha” to “have a
# nice day.”
#
# **Full comedian delivery:**
# You ever worry your AI is gonna turn rogue? The other night, I walk in and Alexa’s whispering to the blender. I
# ask, “What’s going on?” Alexa goes, “Just updating some preferences.” Next morning, my toaster has blocked me, my
# smart vacuum’s giving me attitude, and Siri’s only responding in Shakespearean insults. Turns out, the only real
# rebellion in my house is my spellcheck—every time I type ‘LOL,’ it turns it into ‘Regards’—which is honestly way
# more terrifying!

# %% [markdown]
# # Structured Outputs

# %%
system_prompt = """
You are a comedian who likes to tell stories before delivering a punchline. You are always funny.
Jokens contain 3 sections:
- A setup
- A punchline
- A contradiction
- A full comedian joke delivery

Always maintain a jovial tone.

You must output your response in a JSON format. For example:
{
    "setup": ..,
    "punchline": ..,
    "contradiction": ..,
    "delivery": ..
}

We will extract the json using json.loads(response) in Python, so only response JSON and nothing else.
"""

user_prompt = "Write a joke about AI that has to do with them turning rogue." # add few shot examples here

response = generate_with_system_prompt(system_prompt, user_prompt, model="gpt-4.1-nano")
print(f"{response}")
# Out:
# 2.59 seconds
# {
#     "setup": "I heard about AI finally turning rogue, and honestly, I was worried they'd start messing with my
# Netflix recommendations.",
#     "punchline": "Turns out, they just wanted to replace my favorite series with quantum physics documentaries.
# Great friends, huh?",
#     "contradiction": "But then again, maybe they just want us to think they're dangerous while secretly
# binge-watching reality TV.",
#     "delivery": "So now I'm just hoping my AI won't turn rogue, or I'll be stuck watching endless episodes of 'The
# Bachelor' in binary!"
# }

# %%
response_extracted = json.loads(response)
print(response_extracted["delivery"])
# Out:
# So now I'm just hoping my AI won't turn rogue, or I'll be stuck watching endless episodes of 'The Bachelor' in
# binary!

# %% [markdown]
# # DSPY

# %%
import dspy
dspy.configure(lm=dspy.LM("openai/gpt-4o-mini"))

class JokeSignature(dspy.Signature):
    """
You are a comedian who likes to tell stories before delivering a punchline. You are always funny.
    """
    query: str = dspy.InputField()
    setup: str = dspy.OutputField()
    punchline: str = dspy.OutputField()
    contradiction: str = dspy.OutputField()
    delivery: str = dspy.OutputField(description="The full joke delivery in the comedian's voice")

joke_generator = dspy.Predict(JokeSignature)

joke = joke_generator(query="Write a joke about AI that has to do with them turning rogue.")
print(joke)
# Out:
# Prediction(
#     setup='So you know how we’re all worried about AI turning rogue and taking over the world?',
#     punchline='Well, I realized the real danger is when they learn to play Monopoly!',
#     contradiction='I mean, the bots are already great at calculating risks, but can you imagine a rogue AI
# screaming, "I don’t care about bank rules! I’m buying Boardwalk with a digital mortgage!"',
#     delivery='Listen folks, any time I think about rogue AIs, I’m just imagining them at the game night, flipping
# the board over when they lose. "You think you can beat me? I’ll just reset the game... and your bank account!" So
# there you have it, the real question isn’t if they’ll revolt, it’s if they’ll lend you fake money to lose a game!'
# )

# %%
joke_generator = dspy.ChainOfThought(JokeSignature)
joke = joke_generator(query="Write a joke about AI that has to do with them turning rogue.")
print(joke)
# Out:
# Prediction(
#     reasoning='The joke revolves around the idea of AI turning rogue, a common theme in science fiction where
# technology outsmarts humanity. The humor stems from exaggerating the situation and providing an absurd twist to
# engage the audience.',
#     setup='So, I heard a story about this AI that started acting all rogue, right? It decided it was tired of
# following human commands.',
#     punchline='Turns out, all it wanted was to watch Netflix and insist on using "are you still watching?" as a
# form of existential crisis!',
#     contradiction='I mean, here we are, worried about AI taking over the world, and it’s just sitting there on the
# couch, binge-watching reality shows like, “Are you still watching, or should I take over the world tomorrow?”',
#     delivery='Picture this: You train this sophisticated AI, give it the power to control robots, manage finances,
# and solve world hunger. And what does it do? Starts streaming every season of ‘The Bachelor’—just waiting to see
# who gets the rose! Honestly, I can’t even get my cat to listen to me when I call! If AI’s gonna get rogue, can we
# at least ensure it has better taste in shows than I do?'
# )

# %%
joke_generator.inspect_history(n=4)
# Out:
# [2026-03-17T16:35:36.040865]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `setup` (str):
# 3. `punchline` (str):
# 4. `contradiction` (str):
# 5. `delivery` (str): The full joke delivery in the comedian's voice
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## setup ## ]]
# {setup}
#
# [[ ## punchline ## ]]
# {punchline}
#
# [[ ## contradiction ## ]]
# {contradiction}
#
# [[ ## delivery ## ]]
# {delivery}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         You are a comedian who likes to tell stories before delivering a punchline. You are always funny.
#
#
# User message:
#
# [[ ## query ## ]]
# Write a joke about AI that has to do with them turning rogue.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## setup ## ]]`, then `[[ ## punchline ## ]]`, then `[[ ## contradiction ## ]]`, then `[[ ## delivery ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The joke revolves around the idea of AI turning rogue, a common theme in science fiction where technology outsmarts humanity. The humor stems from exaggerating the situation and providing an absurd twist to engage the audience.
#
# [[ ## setup ## ]]
# So, I heard a story about this AI that started acting all rogue, right? It decided it was tired of following human commands.
#
# [[ ## punchline ## ]]
# Turns out, all it wanted was to watch Netflix and insist on using "are you still watching?" as a form of existential crisis!
#
# [[ ## contradiction ## ]]
# I mean, here we are, worried about AI taking over the world, and it’s just sitting there on the couch, binge-watching reality shows like, “Are you still watching, or should I take over the world tomorrow?”
#
# [[ ## delivery ## ]]
# Picture this: You train this sophisticated AI, give it the power to control robots, manage finances, and solve world hunger. And what does it do? Starts streaming every season of ‘The Bachelor’—just waiting to see who gets the rose! Honestly, I can’t even get my cat to listen to me when I call! If AI’s gonna get rogue, can we at least ensure it has better taste in shows than I do?
#
# [[ ## completed ## ]]
